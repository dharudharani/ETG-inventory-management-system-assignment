# %% [markdown]
# ### **READ DATA FROM JSON**

# %%
import json

fd = open("record.json",'r')
r = fd.read()
fd.close()

record= json.loads(r)

# %%
record
# Out:
# {'30001': {'discount': '10%',
#   'expirydate': '9 months',
#   'name': 'perk',
#   'price': 59,
#   'quantity': 11},
#  '30002': {'discount': '20%',
#   'expirydate': '6 months',
#   'name': 'motherdiary',
#   'price': 58,
#   'quantity': 14},
#  '30003': {'discount': '15%',
#   'expirydate': '10 months',
#   'name': 'kitkat',
#   'price': 20,
#   'quantity': 19},
#  '30004': {'discount': '10%',
#   'expirydate': '9months',
#   'name': 'diarymilk',
#   'price': 100,
#   'quantity': 12},
#  '30005': {'discount': '56%',
#   'expirydate': '6-9 months',
#   'name': 'coco-cola',
#   'price': 70,
#   'quantity': 10},
#  '30006': {'discount': '10%',
#   'expirydate': '6 months',
#   'name': 'spirit',
#   'price': 65,
#   'quantity': 17},
#  '30007': {'discount': '5%',
#   'expirydate': '365days',
#   'name': "Kwality Wall's",
#   'price': 78,
#   'quantity': 10},
#  '30008': {'discount': '21%',
#   'expirydate': '12 months',
#   'name': 'kissan jam',
#   'price': 169,
#   'quantity': 30},
# ...

# %% [markdown]
# ## ADDING NEW ITEMS INTO INVENTORY

# %%
id = str(input("Enter product id:"))
name = str(input("Enter name:"))
price= int(input("Enter price:"))
quantity= int(input("Enter quantity:"))
discount= (input("Enter discount:"))
expirydate=str(input("Enter expirydate:"))

record[id] = {'name': name, 'price': price, 'quantity': quantity,'discount':discount,'expirydate':expirydate}

js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()

# %%
record
# Out:
# {'30001': {'discount': '10%',
#   'expirydate': '9 months',
#   'name': 'perk',
#   'price': 59,
#   'quantity': 11},
#  '30002': {'discount': '20%',
#   'expirydate': '6 months',
#   'name': 'motherdiary',
#   'price': 58,
#   'quantity': 14},
#  '30003': {'discount': '15%',
#   'expirydate': '10 months',
#   'name': 'kitkat',
#   'price': 20,
#   'quantity': 19},
#  '30004': {'discount': '10%',
#   'expirydate': '9months',
#   'name': 'diarymilk',
#   'price': 100,
#   'quantity': 12},
#  '30005': {'discount': '56%',
#   'expirydate': '6-9 months',
#   'name': 'coco-cola',
#   'price': 70,
#   'quantity': 10},
#  '30006': {'discount': '10%',
#   'expirydate': '6 months',
#   'name': 'spirit',
#   'price': 65,
#   'quantity': 17},
#  '30007': {'discount': '5%',
#   'expirydate': '365days',
#   'name': "Kwality Wall's",
#   'price': 78,
#   'quantity': 10},
#  '30008': {'discount': '21%',
#   'expirydate': '12 months',
#   'name': 'kissan jam',
#   'price': 169,
#   'quantity': 30},
# ...

# %%
record=json.loads(r)

# %% [markdown]
# ### ***DELETING ITEM FROM INVENTORY***

# %%
del record['30030']

# %%
record
# Out:
# {'30001': {'discount': '10%',
#   'expirydate': '9 months',
#   'name': 'perk',
#   'price': 59,
#   'quantity': 11},
#  '30002': {'discount': '20%',
#   'expirydate': '6 months',
#   'name': 'motherdiary',
#   'price': 58,
#   'quantity': 14},
#  '30003': {'discount': '15%',
#   'expirydate': '10 months',
#   'name': 'kitkat',
#   'price': 20,
#   'quantity': 19},
#  '30004': {'discount': '10%',
#   'expirydate': '9months',
#   'name': 'diarymilk',
#   'price': 100,
#   'quantity': 12},
#  '30005': {'discount': '56%',
#   'expirydate': '6-9 months',
#   'name': 'coco-cola',
#   'price': 70,
#   'quantity': 10},
#  '30006': {'discount': '10%',
#   'expirydate': '6 months',
#   'name': 'spirit',
#   'price': 65,
#   'quantity': 17},
#  '30007': {'discount': '5%',
#   'expirydate': '365days',
#   'name': "Kwality Wall's",
#   'price': 78,
#   'quantity': 10},
#  '30008': {'discount': '21%',
#   'expirydate': '12 months',
#   'name': 'kissan jam',
#   'price': 169,
#   'quantity': 30},
# ...

# %%
len(record)
# Out:
# 33
